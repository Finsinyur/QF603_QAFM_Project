# %%
# Import WRDS library
import wrds
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
import os

# %%
def read_sql_script(fname):
    fd = open(fname, 'r')
    sqlFile = fd.read()
    fd.close()

    return sqlFile


# Get current path
this_path = os.path.abspath(os.curdir)
print(this_path)

# Define sql file names
# these will be used as a global variable
query_historical_prices = read_sql_script('/Users/abigail/Desktop/SMU/QF603/get_historical_prices.sql')
query_shares_outstanding = read_sql_script('/Users/abigail/Desktop/SMU/QF603/get_shares_outstanding.sql')
#query_historical_one_price = read_sql_script('/Users/abigail/Desktop/SMU/QF603/get_historical_price_1d.sql')


# Establish live connection; requires user login (passwords will be masked)
db = wrds.Connection() # this will be used as a global variable


def get_historical_prices(isin, start_date, end_date):
    
    print(f'Extracting historical prices for {isin}...')

    df =\
    (
        db
        .raw_sql(
            query_historical_prices.format(isin, start_date, end_date), 
            date_cols = ['trade_date']
            )
    )

    if df.empty:
        print('Dataframe is empty. No results was returned!')
    
    print('--------------------------------------------------')

    return df



def get_historical_one_price(isin, date):
    
    print(f'Extracting historical prices for {isin}...')

    df =\
    (
        db
        .raw_sql(
            query_historical_one_price.format(isin, date), 
            date_cols = ['trade_date']
            )
    )

    if df.empty:
        print('Dataframe is empty. No results was returned!')
    
    print('--------------------------------------------------')

    return df
# Out:
# /Users/abigail/Desktop/SMU/QF603
# Enter your WRDS username [abigail]:abigailcjh
# Enter your password:········
# WRDS recommends setting up a .pgpass file.
# Create .pgpass file now [y/n]?: y
# Created .pgpass file successfully.
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# Done

# %%
# #first iteration

# ftse_rebal = pd.read_csv('ftse100_rebalancing_summary.csv')


# ftse_rebal["post_date"] =\
#     (
#         ftse_rebal["Post Date"]
#         .apply(lambda x: datetime.strptime(x,'%Y-%m-%d'))
#     )

# #pd.to_datetime(series, format=)


# ftse_rebal["start_date"] =\
#     (
#         ftse_rebal["post_date"] - timedelta(days = 10)
#     )
    
# ftse_rebal["end_date"] =\
#     (
#         ftse_rebal["post_date"] + timedelta(days = 31)
#     )

# ftse_rebal["fmt_start_date"] =\
#     (
#         ftse_rebal["start_date"]
#         .apply(lambda x: datetime.strftime(x,"%d/%m/%Y"))
#     )
    
# ftse_rebal["fmt_end_date"] =\
#     (
#         ftse_rebal["end_date"]
#         .apply(lambda x: datetime.strftime(x,"%d/%m/%Y"))
#     )


# target_isins = ftse_rebal["ISIN\n"]
# start_dates = ftse_rebal["fmt_start_date"]
# end_dates = ftse_rebal["fmt_end_date"]   
    
    


# historical_prices =\
#     (
#         pd.
#         concat(
#             map(
#                 get_historical_prices,
#                 target_isins,
#                 start_dates,
#                 end_dates
#             )
#         )
#     )

# (
#         historical_prices
#         .to_csv(
#             f'/Users/abigail/Desktop/SMU/QF603/output/historical_prices_ftse_rebal_20230923.csv',
#             index = False
#             )
# )

# print('===================================================')

# %%
#second iteration

ftse_full_rebal = pd.read_csv('ftse_10y_rebal_records.csv')


ftse_full_rebal["post_date"] =\
    (
        ftse_full_rebal["Post Date"]
        .apply(lambda x: datetime.strptime(x,'%d/%m/%Y'))
    )

#pd.to_datetime(series, format=)



ftse_full_rebal["start_date"] =\
    (
        ftse_full_rebal["post_date"] - timedelta(days = 50)
    )
    
ftse_full_rebal["end_date"] =\
    (
        ftse_full_rebal["post_date"] + timedelta(days = 50)
    )

ftse_full_rebal["fmt_start_date"] =\
    (
        ftse_full_rebal["start_date"]
        .apply(lambda x: datetime.strftime(x,"%d/%m/%Y"))
    )
    
ftse_full_rebal["fmt_end_date"] =\
    (
        ftse_full_rebal["end_date"]
        .apply(lambda x: datetime.strftime(x,"%d/%m/%Y"))
    )




target_isins = ftse_full_rebal["ISIN"]
start_dates = ftse_full_rebal["fmt_start_date"]
end_dates = ftse_full_rebal["fmt_end_date"]   



historical_prices =\
    (
        pd.
        concat(
            map(
                get_historical_prices,
                target_isins,
                start_dates,
                end_dates
            )
        )
    )

(
        historical_prices
        .to_csv(
            f'/Users/abigail/Desktop/SMU/QF603/output/extract_ftse_10y_rebal_records.csv',
            index = False
            )
)

print('===================================================')
# Out:
# Extracting historical prices for GI000A0F6407...
# --------------------------------------------------
# Extracting historical prices for GB00BF8Q6K64...
# --------------------------------------------------
# Extracting historical prices for GB00BM8NFJ84...
# --------------------------------------------------
# Extracting historical prices for GB00BMCYKB41...
# --------------------------------------------------
# Extracting historical prices for GB00B23K0M20...
# --------------------------------------------------
# Extracting historical prices for GB00BG5KQW09...
# --------------------------------------------------
# Extracting historical prices for GB00B14SKR37...
# --------------------------------------------------
# Extracting historical prices for GB0009633180...
# --------------------------------------------------
# Extracting historical prices for GB0001826634...
# --------------------------------------------------
# Extracting historical prices for GG00BMD8MJ76...
# --------------------------------------------------
# Extracting historical prices for GB00B0LCW083...
# --------------------------------------------------
# Extracting historical prices for BMG4593F1389...
# --------------------------------------------------
# Extracting historical prices for GB00BZ4BQC70...
# --------------------------------------------------
# Extracting historical prices for GB0031274896...
# --------------------------------------------------
# Extracting historical prices for GB00BY7QYJ50...
# --------------------------------------------------
# Extracting historical prices for GB00BMT9K014...
# --------------------------------------------------
# Extracting historical prices for GB0006825383...
# --------------------------------------------------
# Extracting historical prices for GB00BNTVWJ75...
# --------------------------------------------------
# Extracting historical prices for GB00B1Z4ST84...
# --------------------------------------------------
# Extracting historical prices for GB00BD2NCM38...
# --------------------------------------------------
# Extracting historical prices for GB0030927254...
# --------------------------------------------------
# Extracting historical prices for GB0001367019...
# --------------------------------------------------
# Extracting historical prices for GB00B23K0M20...
# --------------------------------------------------
# Extracting historical prices for GB00BRJ7R218...
# Dataframe is empty. No results was returned!
# --------------------------------------------------
# Extracting historical prices for GB00BLWDVR75...
# --------------------------------------------------
# Extracting historical prices for GB0004478896...
# --------------------------------------------------
# Extracting historical prices for GB00BGLP8L22...
# --------------------------------------------------
# Extracting historical prices for GB0008481250...
# --------------------------------------------------
# Extracting historical prices for GB0006439003...
# --------------------------------------------------
# Extracting historical prices for GB0001500809...
# --------------------------------------------------
# Extracting historical prices for GB00B29H4253...
# --------------------------------------------------
# Extracting historical prices for GB0009296665...
# --------------------------------------------------
# Extracting historical prices for GI000A0F6407...
# --------------------------------------------------
# Extracting historical prices for GB00BPJHV584...
# --------------------------------------------------
# Extracting historical prices for GB00BMT9K014...
# --------------------------------------------------
# Extracting historical prices for GB00B1Z4ST84...
# --------------------------------------------------
# Extracting historical prices for GB00BF8Q6K64...
# --------------------------------------------------
# Extracting historical prices for GB00BYQ0JC66...
# --------------------------------------------------
# Extracting historical prices for GB0009633180...
# --------------------------------------------------
# Extracting historical prices for JE00BMDKH437...
# --------------------------------------------------
# Extracting historical prices for GB00BMCF8689...
# --------------------------------------------------
# Extracting historical prices for GB00BMBVGQ36...
# --------------------------------------------------
# Extracting historical prices for GB00BJP5HK17...
# --------------------------------------------------
# Extracting historical prices for GB00BYT1DJ19...
# --------------------------------------------------
# Extracting historical prices for GB00B0H2K534...
# --------------------------------------------------
# Extracting historical prices for GB0009465807...
# --------------------------------------------------
# Extracting historical prices for GB00BF8Q6K64...
# --------------------------------------------------
# Extracting historical prices for GG00BB0RDB98...
# --------------------------------------------------
# Extracting historical prices for GG00BGJYPP46...
# --------------------------------------------------
# Extracting historical prices for GB00BD3VFW73...
# --------------------------------------------------
# Extracting historical prices for GB0003466074...
# --------------------------------------------------
# Extracting historical prices for IE0003864109...
# --------------------------------------------------
# Extracting historical prices for GB00BMBVGQ36...
# --------------------------------------------------
# Extracting historical prices for GB00B0LCW083...
# --------------------------------------------------
# Extracting historical prices for GB0005576813...
# --------------------------------------------------
# Extracting historical prices for GG00BJ0JVY01...
# --------------------------------------------------
# Extracting historical prices for GB00B1Z4ST84...
# --------------------------------------------------
# Extracting historical prices for GB00BY2Z0H74...
# --------------------------------------------------
# Extracting historical prices for GG00B90J5Z95...
# --------------------------------------------------
# Extracting historical prices for GB00B29H4253...
# --------------------------------------------------
# Extracting historical prices for GB00BD2NCM38...
# --------------------------------------------------
# Extracting historical prices for SG9999003735...
# --------------------------------------------------
# Extracting historical prices for GB0030927254...
# --------------------------------------------------
# Extracting historical prices for GB00BDFGHW41...
# --------------------------------------------------
# Extracting historical prices for GB00BF4HYT85...
# --------------------------------------------------
# Extracting historical prices for GB00B033F229...
# --------------------------------------------------
# Extracting historical prices for GB0033986497...
# --------------------------------------------------
# Extracting historical prices for GB0005800072...
# --------------------------------------------------
# Extracting historical prices for GB00BDFBVT43...
# --------------------------------------------------
# Extracting historical prices for GB00BY2Z0H74...
# --------------------------------------------------
# Extracting historical prices for GB00B1L5QH97...
# --------------------------------------------------
# Extracting historical prices for GB00BDVZYZ77...
# --------------------------------------------------
# Extracting historical prices for GB00BF345X11...
# --------------------------------------------------
# Extracting historical prices for GB00BJGTLF51...
# --------------------------------------------------
# Extracting historical prices for GB00BNK9TP58...
# --------------------------------------------------
# Extracting historical prices for GB0006928617...
# --------------------------------------------------
# Extracting historical prices for GB00BFXYH242...
# --------------------------------------------------
# Extracting historical prices for GB00B23K0M20...
# --------------------------------------------------
# Extracting historical prices for GB00B15FWH70...
# --------------------------------------------------
# Extracting historical prices for GB00BMMV6B79...
# --------------------------------------------------
# Extracting historical prices for GB00BL6K5J42...
# --------------------------------------------------
# Extracting historical prices for GB00B71N6K86...
# --------------------------------------------------
# Extracting historical prices for GB0005576813...
# --------------------------------------------------
# Extracting historical prices for GG00B1ZBD492...
# --------------------------------------------------
# Extracting historical prices for GB0031544546...
# --------------------------------------------------
# Extracting historical prices for JE00B6T5S470...
# --------------------------------------------------
# Extracting historical prices for GB0009039941...
# --------------------------------------------------
# Extracting historical prices for GB00B018CS46...
# --------------------------------------------------
# Extracting historical prices for GB0030474687...
# --------------------------------------------------
# Extracting historical prices for GB00BMV92D64...
# --------------------------------------------------
# Extracting historical prices for GB0001500809...
# --------------------------------------------------
# Extracting historical prices for GB00BYV8MN78...
# --------------------------------------------------
# Extracting historical prices for GB00BJTNFH41...
# --------------------------------------------------
# Extracting historical prices for GB00BNYK8G86...
# --------------------------------------------------
# Extracting historical prices for GB0009633180...
# --------------------------------------------------
# Extracting historical prices for GB0003096442...
# --------------------------------------------------
# Extracting historical prices for GB00BZ4BQC70...
# --------------------------------------------------
# Extracting historical prices for GB00BL9ZF303...
# --------------------------------------------------
# Extracting historical prices for GB00B1Z4ST84...
# --------------------------------------------------
# Extracting historical prices for GB00B0YG1K06...
# --------------------------------------------------
# Extracting historical prices for GB0000667013...
# --------------------------------------------------
# Extracting historical prices for GB00BN44P254...
# --------------------------------------------------
# Extracting historical prices for GB0008910555...
# --------------------------------------------------
# Extracting historical prices for GB00BND88V85...
# --------------------------------------------------
# Extracting historical prices for GB00BD8HBD32...
# --------------------------------------------------
# Extracting historical prices for GB00BNYK8G86...
# --------------------------------------------------
# Extracting historical prices for GB00BY7QYJ50...
# --------------------------------------------------
# Extracting historical prices for GB00BL6K5J42...
# --------------------------------------------------
# Extracting historical prices for NL0012015705...
# --------------------------------------------------
# Extracting historical prices for GB0005758098...
# --------------------------------------------------
# Extracting historical prices for GB0006043169...
# --------------------------------------------------
# Extracting historical prices for GB00BMV92D64...
# --------------------------------------------------
# Extracting historical prices for GB0001500809...
# --------------------------------------------------
# Extracting historical prices for GB0009465807...
# --------------------------------------------------
# Extracting historical prices for GB00BL6C2002...
# --------------------------------------------------
# Extracting historical prices for GB00BMVQDZ64...
# --------------------------------------------------
# Extracting historical prices for JE00BD3QJR55...
# --------------------------------------------------
# Extracting historical prices for GB0033986497...
# --------------------------------------------------
# Extracting historical prices for GG00BJL5FH87...
# --------------------------------------------------
# Extracting historical prices for GB00BMT9K014...
# --------------------------------------------------
# Extracting historical prices for GB00B1Z4ST84...
# --------------------------------------------------
# Extracting historical prices for GB0007323586...
# --------------------------------------------------
# Extracting historical prices for GB00BYWVDP49...
# --------------------------------------------------
# Extracting historical prices for GB00BNLPYF73...
# --------------------------------------------------
# Extracting historical prices for GB00BNK9TP58...
# --------------------------------------------------
# Extracting historical prices for GB0006043169...
# --------------------------------------------------
# Extracting historical prices for GB00BNNTLN49...
# --------------------------------------------------
# Extracting historical prices for GB0007323586...
# --------------------------------------------------
# Extracting historical prices for GB0009465807...
# --------------------------------------------------
# Extracting historical prices for GB0002418548...
# --------------------------------------------------
# Extracting historical prices for GB0003395000...
# --------------------------------------------------
# Extracting historical prices for GB00BK7YQK64...
# --------------------------------------------------
# Extracting historical prices for GB00BYYTFB60...
# --------------------------------------------------
# Extracting historical prices for GG00BPFJTF46...
# --------------------------------------------------
# Extracting historical prices for GB0007826091...
# --------------------------------------------------
# Extracting historical prices for LU1072616219...
# --------------------------------------------------
# Extracting historical prices for GB00BDFGHW41...
# --------------------------------------------------
# Extracting historical prices for GB00BF4HYT85...
# --------------------------------------------------
# Extracting historical prices for GB00B6XZKY75...
# --------------------------------------------------
# Extracting historical prices for GB00B14SKR37...
# --------------------------------------------------
# Extracting historical prices for GB00BYX7JT74...
# --------------------------------------------------
# Extracting historical prices for GB00BYWWHR75...
# --------------------------------------------------
# Extracting historical prices for GB00BJ7HMW26...
# --------------------------------------------------
# Extracting historical prices for GB0003753778...
# --------------------------------------------------
# Extracting historical prices for GB00BK7YQK64...
# --------------------------------------------------
# Extracting historical prices for GG00BLPHZK78...
# --------------------------------------------------
# Extracting historical prices for GB00BN4HT335...
# --------------------------------------------------
# Extracting historical prices for GB0033986497...
# --------------------------------------------------
# Extracting historical prices for GB00BMTS0Z37...
# --------------------------------------------------
# Extracting historical prices for GB00B02QND93...
# --------------------------------------------------
# Extracting historical prices for GG00B1Z5FH87...
# --------------------------------------------------
# Extracting historical prices for GB00B7N0K053...
# --------------------------------------------------
# Extracting historical prices for GB0009376368...
# --------------------------------------------------
# Extracting historical prices for GB00BMV92D64...
# --------------------------------------------------
# Extracting historical prices for GB00BKM2MW97...
# --------------------------------------------------
# Extracting historical prices for GI000A0F6407...
# --------------------------------------------------
# Extracting historical prices for GB00BJTNFH41...
# --------------------------------------------------
# Extracting historical prices for GB00BDD85M81...
# --------------------------------------------------
# Extracting historical prices for GB00BF8J3Z99...
# --------------------------------------------------
# Extracting historical prices for GB00BZCNLL95...
# --------------------------------------------------
# Extracting historical prices for GB00BKX9C181...
# --------------------------------------------------
# Extracting historical prices for GB0031215220...
# --------------------------------------------------
# Extracting historical prices for GB00B033F229...
# --------------------------------------------------
# Extracting historical prices for GB00BD8HBD32...
# --------------------------------------------------
# Extracting historical prices for GB00B7KR2P84...
# --------------------------------------------------
# Extracting historical prices for GB0002418548...
# --------------------------------------------------
# Extracting historical prices for GB00BYYW3C20...
# --------------------------------------------------
# Extracting historical prices for IM00B5VQMV65...
# --------------------------------------------------
# Extracting historical prices for GB00BYYTFB60...
# --------------------------------------------------
# Extracting historical prices for GB00BKP36R26...
# --------------------------------------------------
# Extracting historical prices for GG00BJL5FH87...
# --------------------------------------------------
# Extracting historical prices for GB0003450359...
# --------------------------------------------------
# Extracting historical prices for GB0033195214...
# --------------------------------------------------
# Extracting historical prices for GB0007388407...
# --------------------------------------------------
# Extracting historical prices for GB00B1JQDM80...
# --------------------------------------------------
# Extracting historical prices for GB00BYNVD082...
# --------------------------------------------------
# Extracting historical prices for GB0005758098...
# --------------------------------------------------
# Extracting historical prices for GB00BDFBVT43...
# --------------------------------------------------
# Extracting historical prices for GB0007873697...
# --------------------------------------------------
# Extracting historical prices for GB0007958233...
# --------------------------------------------------
# Extracting historical prices for GB00B6YTLS95...
# --------------------------------------------------
# Extracting historical prices for GI000A0F6407...
# --------------------------------------------------
# Extracting historical prices for GB00BD8DR117...
# --------------------------------------------------
# Extracting historical prices for GB00B45C9X44...
# --------------------------------------------------
# Extracting historical prices for GB00BJ7HMW26...
# --------------------------------------------------
# Extracting historical prices for GB00BYYW3C20...
# --------------------------------------------------
# Extracting historical prices for GB00B2QPKJ12...
# --------------------------------------------------
# Extracting historical prices for GB00BKY40Q38...
# --------------------------------------------------
# Extracting historical prices for GB00BZ14BX56...
# --------------------------------------------------
# Extracting historical prices for GG00BFYT9H72...
# --------------------------------------------------
# Extracting historical prices for GB0004478896...
# --------------------------------------------------
# Extracting historical prices for GB0031232498...
# --------------------------------------------------
# Extracting historical prices for GB00BYT1DJ19...
# --------------------------------------------------
# Extracting historical prices for GB0033195214...
# --------------------------------------------------
# Extracting historical prices for GB00BD7XPJ64...
# --------------------------------------------------
# Extracting historical prices for GB00BNNTLN49...
# --------------------------------------------------
# Extracting historical prices for GB0031544546...
# --------------------------------------------------
# Extracting historical prices for GB00B0YG1K06...
# --------------------------------------------------
# Extracting historical prices for GB0008025412...
# --------------------------------------------------
# Extracting historical prices for DE000TUAG505...
# --------------------------------------------------
# Extracting historical prices for GB0001500809...
# --------------------------------------------------
# Extracting historical prices for SG9999003735...
# --------------------------------------------------
# Extracting historical prices for IE00B010DT83...
# --------------------------------------------------
# Extracting historical prices for GB00BLY2F708...
# --------------------------------------------------
# Extracting historical prices for GB00B7KR2P84...
# --------------------------------------------------
# Extracting historical prices for GB00B2QPKJ12...
# --------------------------------------------------
# Extracting historical prices for GB00BJVQC708...
# --------------------------------------------------
# Extracting historical prices for BMG4593F1389...
# --------------------------------------------------
# Extracting historical prices for GB00BKX5CN86...
# --------------------------------------------------
# Extracting historical prices for GB00BYQ46T41...
# --------------------------------------------------
# Extracting historical prices for GG00B1ZBD492...
# --------------------------------------------------
# Extracting historical prices for GG00BBHXCL35...
# --------------------------------------------------
# Extracting historical prices for GB00BKDRYJ47...
# --------------------------------------------------
# Extracting historical prices for GB00BFFK8T45...
# --------------------------------------------------
# Extracting historical prices for GB00BY9D0Y18...
# --------------------------------------------------
# Extracting historical prices for GB00BJ7HMW26...
# --------------------------------------------------
# Extracting historical prices for JE00BD3QJR55...
# --------------------------------------------------
# Extracting historical prices for GB00BG0TPX62...
# --------------------------------------------------
# Extracting historical prices for GB00B0LCW083...
# --------------------------------------------------
# Extracting historical prices for GB0006834344...
# --------------------------------------------------
# Extracting historical prices for GB0031274896...
# --------------------------------------------------
# Extracting historical prices for GB0005758098...
# --------------------------------------------------
# Extracting historical prices for GB00BMX3W479...
# --------------------------------------------------
# Extracting historical prices for GB00BJ1F4N75...
# --------------------------------------------------
# Extracting historical prices for JE00B6T5S470...
# --------------------------------------------------
# Extracting historical prices for GG00B1W3VF54...
# --------------------------------------------------
# Extracting historical prices for GB0001048619...
# --------------------------------------------------
# Extracting historical prices for GB00BKDTK925...
# --------------------------------------------------
# Extracting historical prices for GB00BJDQQ870...
# --------------------------------------------------
# Extracting historical prices for GB00BVG1CF25...
# --------------------------------------------------
# Extracting historical prices for GB0006640972...
# --------------------------------------------------
# Extracting historical prices for GI000A0F6407...
# --------------------------------------------------
# Extracting historical prices for GB00BBG9VN75...
# --------------------------------------------------
# Extracting historical prices for GB00BD8HBD32...
# --------------------------------------------------
# Extracting historical prices for GB00B7KR2P84...
# --------------------------------------------------
# Extracting historical prices for GB00BYZN9041...
# --------------------------------------------------
# Extracting historical prices for GB00B0LCW083...
# --------------------------------------------------
# Extracting historical prices for GB00BN4HT335...
# --------------------------------------------------
# Extracting historical prices for GB00BM8Q5M07...
# --------------------------------------------------
# Extracting historical prices for GB00BCRX1J15...
# --------------------------------------------------
# Extracting historical prices for GB00BZ0D6727...
# --------------------------------------------------
# Extracting historical prices for GB0004915632...
# --------------------------------------------------
# Extracting historical prices for GB00B1JQDM80...
# --------------------------------------------------
# Extracting historical prices for GB00BH3VJ782...
# --------------------------------------------------
# Extracting historical prices for GB00B02QND93...
# --------------------------------------------------
# Extracting historical prices for GG00B1Z5FH87...
# --------------------------------------------------
# Extracting historical prices for GB00BMX64W89...
# --------------------------------------------------
# Extracting historical prices for GB00B03HDJ73...
# --------------------------------------------------
# Extracting historical prices for GB00BFZNLB60...
# --------------------------------------------------
# Extracting historical prices for GB0002945029...
# --------------------------------------------------
# Extracting historical prices for IM00B5VQMV65...
# --------------------------------------------------
# Extracting historical prices for GB00B012TP20...
# --------------------------------------------------
# Extracting historical prices for GB00BKX5CN86...
# --------------------------------------------------
# Extracting historical prices for GB0004915632...
# --------------------------------------------------
# Extracting historical prices for GB00BJ62K685...
# --------------------------------------------------
# Extracting historical prices for GB00BGXQNP29...
# --------------------------------------------------
# Extracting historical prices for GB00B60BD277...
# --------------------------------------------------
# Extracting historical prices for GB00B5N0P849...
# --------------------------------------------------
# Extracting historical prices for GB00BMSKPJ95...
# --------------------------------------------------
# Extracting historical prices for GB00B61D2N63...
# --------------------------------------------------
# Extracting historical prices for GB00BN7CG237...
# --------------------------------------------------
# Extracting historical prices for GB00BG0TPX62...
# --------------------------------------------------
# Extracting historical prices for BMG4593F1389...
# --------------------------------------------------
# Extracting historical prices for GB00BKX5CN86...
# --------------------------------------------------
# Extracting historical prices for GB0004866223...
# --------------------------------------------------
# Extracting historical prices for GB0004915632...
# --------------------------------------------------
# Extracting historical prices for GB00BYNVD082...
# --------------------------------------------------
# Extracting historical prices for GB00BYM1K758...
# --------------------------------------------------
# Extracting historical prices for GB00BDVZYZ77...
# --------------------------------------------------
# Extracting historical prices for GB00BGJWTR88...
# --------------------------------------------------
# Extracting historical prices for GB00BWFGQN14...
# --------------------------------------------------
# Extracting historical prices for GB00BNLPYF73...
# --------------------------------------------------
# Extracting historical prices for GB00B1VYCH82 ...
# Dataframe is empty. No results was returned!
# --------------------------------------------------
# Extracting historical prices for GB00BVG1CF25...
# --------------------------------------------------
# Extracting historical prices for GB00B0YG1K06...
# --------------------------------------------------
# Extracting historical prices for GB00BDHXPG30...
# --------------------------------------------------
# Extracting historical prices for GB00BFFK8T45...
# --------------------------------------------------
# Extracting historical prices for GB00BDD85M81...
# --------------------------------------------------
# Extracting historical prices for GB00BYNVD082...
# --------------------------------------------------
# Extracting historical prices for IL0011284465...
# --------------------------------------------------
# Extracting historical prices for IM00BH3JLY32...
# --------------------------------------------------
# Extracting historical prices for GB00BNR4T868...
# --------------------------------------------------
# Extracting historical prices for GB00BDGT2M75...
# --------------------------------------------------
# Extracting historical prices for GB00BG12Y042...
# --------------------------------------------------
# Extracting historical prices for GB00B01FLG62...
# --------------------------------------------------
# Extracting historical prices for IM00B5VQMV65...
# --------------------------------------------------
# Extracting historical prices for GB00BD45SH49...
# --------------------------------------------------
# Extracting historical prices for GB00B1VNST91...
# --------------------------------------------------
# Extracting historical prices for GB00B1JQDM80...
# --------------------------------------------------
# Extracting historical prices for GB00B8HX8Z88...
# --------------------------------------------------
# Extracting historical prices for GB00B3MBS747...
# --------------------------------------------------
# Extracting historical prices for GB00BJ62K685...
# --------------------------------------------------
# Extracting historical prices for GB00B43G0577...
# --------------------------------------------------
# Extracting historical prices for BMG7300G1096...
# --------------------------------------------------
# Extracting historical prices for GB00BVG1CF25...
# --------------------------------------------------
# Extracting historical prices for GB00BMSKPJ95...
# --------------------------------------------------
# Extracting historical prices for GB00B61D2N63...
# --------------------------------------------------
# Extracting historical prices for GB0000485838...
# --------------------------------------------------
# Extracting historical prices for GB00BF8J3Z99...
# --------------------------------------------------
# Extracting historical prices for GB00B1P6ZR11...
# --------------------------------------------------
# Extracting historical prices for GB00BD822578...
# --------------------------------------------------
# Extracting historical prices for GB00BF448H58...
# --------------------------------------------------
# Extracting historical prices for GB00BRB37M78...
# --------------------------------------------------
# Extracting historical prices for GB0003718474...
# --------------------------------------------------
# Extracting historical prices for GB00BK7YQK64...
# --------------------------------------------------
# Extracting historical prices for GB00B0PPFY88...
# --------------------------------------------------
# Extracting historical prices for GB0004657408...
# --------------------------------------------------
# Extracting historical prices for GB00BYM1K758...
# --------------------------------------------------
# Extracting historical prices for GB00BP37WF17...
# --------------------------------------------------
# Extracting historical prices for GB00BDVZYZ77...
# --------------------------------------------------
# Extracting historical prices for GB00BKM2MW97...
# --------------------------------------------------
# Extracting historical prices for GB0009697037...
# --------------------------------------------------
# Extracting historical prices for GB00BP0S1D85...
# --------------------------------------------------
# Extracting historical prices for GB00BD3VFW73...
# --------------------------------------------------
# Extracting historical prices for GB0003085445...
# --------------------------------------------------
# Extracting historical prices for GB00BKLXD974...
# --------------------------------------------------
# Extracting historical prices for GB0004052071...
# --------------------------------------------------
# Extracting historical prices for GB00BKX5CN86...
# --------------------------------------------------
# Extracting historical prices for GB00BDZT6P94...
# --------------------------------------------------
# Extracting historical prices for GB00BQVVS097...
# --------------------------------------------------
# Extracting historical prices for GB00BLP57Y95...
# --------------------------------------------------
# Extracting historical prices for GB00B02QND93...
# --------------------------------------------------
# Extracting historical prices for BMG7300G1096...
# --------------------------------------------------
# Extracting historical prices for GB00B0YG1K06...
# --------------------------------------------------
# Extracting historical prices for NL0012650360...
# --------------------------------------------------
# Extracting historical prices for GB0008220112...
# --------------------------------------------------
# Extracting historical prices for GB00BYQB9V88...
# --------------------------------------------------
# Extracting historical prices for GI000A0F6407...
# --------------------------------------------------
# Extracting historical prices for GB00BDHXPG30...
# --------------------------------------------------
# Extracting historical prices for GB00BLJNXL82...
# --------------------------------------------------
# Extracting historical prices for GB0007365546...
# --------------------------------------------------
# Extracting historical prices for GB00B7FC0762...
# --------------------------------------------------
# Extracting historical prices for GB00B41H7391...
# --------------------------------------------------
# Extracting historical prices for BMG702782084...
# --------------------------------------------------
# Extracting historical prices for GB00B1Z4ST84...
# --------------------------------------------------
# Extracting historical prices for GB00BDVZYZ77...
# --------------------------------------------------
# Extracting historical prices for GG00BV54HY67...
# --------------------------------------------------
# Extracting historical prices for GB00BLRLH124...
# --------------------------------------------------
# Extracting historical prices for GB00BJTNFH41...
# --------------------------------------------------
# Extracting historical prices for GG00BQBFY362...
# --------------------------------------------------
# Extracting historical prices for GB00B4YZN328...
# --------------------------------------------------
# Extracting historical prices for GB00B126KH97...
# --------------------------------------------------
# Extracting historical prices for GB00BLWDVP51...
# --------------------------------------------------
# Extracting historical prices for GB00B01FLG62...
# --------------------------------------------------
# Extracting historical prices for GB00B0LCW083...
# --------------------------------------------------
# Extracting historical prices for GB0006834344...
# --------------------------------------------------
# Extracting historical prices for GB0004866223...
# --------------------------------------------------
# Extracting historical prices for GB00BNGDN821...
# --------------------------------------------------
# Extracting historical prices for GG00BPFJTF46...
# --------------------------------------------------
# Extracting historical prices for GB00B5ZN1N88...
# --------------------------------------------------
# Extracting historical prices for GB00B0DG3H29...
# --------------------------------------------------
# Extracting historical prices for GB0007892358...
# --------------------------------------------------
# Extracting historical prices for GB00BYT18307...
# --------------------------------------------------
# Extracting historical prices for GB00B1P6ZR11...
# --------------------------------------------------
# Extracting historical prices for GB00B23K0M20...
# --------------------------------------------------
# Extracting historical prices for GB00B14SKR37...
# --------------------------------------------------
# Extracting historical prices for GB00B4Y7R145...
# --------------------------------------------------
# Extracting historical prices for GB00B1YKG049...
# --------------------------------------------------
# Extracting historical prices for GB00B41H7391...
# --------------------------------------------------
# Extracting historical prices for GB00B082RF11...
# --------------------------------------------------
# Extracting historical prices for JE00BVRZ8S85...
# --------------------------------------------------
# Extracting historical prices for GB00BLDYK618...
# --------------------------------------------------
# Extracting historical prices for GG00B8P59C08...
# --------------------------------------------------
# Extracting historical prices for GB00BD3VFW73...
# --------------------------------------------------
# Extracting historical prices for GB00BK5V9445...
# --------------------------------------------------
# Extracting historical prices for GB00BTC0LB89...
# --------------------------------------------------
# Extracting historical prices for GB00B1XH2C03...
# --------------------------------------------------
# Extracting historical prices for GB00B1VNST91...
# --------------------------------------------------
# Extracting historical prices for GB00B01QGK86...
# --------------------------------------------------
# Extracting historical prices for GB00BD7XPJ64...
# --------------------------------------------------
# Extracting historical prices for GB00BQVVS097...
# --------------------------------------------------
# Extracting historical prices for JE00B6T5S470...
# --------------------------------------------------
# Extracting historical prices for IE00B1RR8406...
# --------------------------------------------------
# Extracting historical prices for GB00BK9RKT01...
# --------------------------------------------------
# Extracting historical prices for GB00BLJNXL82...
# --------------------------------------------------
# Extracting historical prices for GB00BJVD3B28...
# --------------------------------------------------
# Extracting historical prices for IM00B5VQMV65...
# --------------------------------------------------
# Extracting historical prices for GB0004478896...
# --------------------------------------------------
# Extracting historical prices for GB00B1JQBT10...
# --------------------------------------------------
# Extracting historical prices for JE00B6T5S470...
# --------------------------------------------------
# Extracting historical prices for GB00BYM8GJ06...
# --------------------------------------------------
# Extracting historical prices for GB00B14SKR37...
# --------------------------------------------------
# Extracting historical prices for GB00BYPHNG03...
# --------------------------------------------------
# Extracting historical prices for GB00BD6GN030...
# --------------------------------------------------
# Extracting historical prices for GG00BNW1QK33...
# --------------------------------------------------
# Extracting historical prices for GB00B0LCW083...
# --------------------------------------------------
# Extracting historical prices for GB0004270301...
# --------------------------------------------------
# Extracting historical prices for GB00B09LSH68...
# --------------------------------------------------
# Extracting historical prices for GB0001528156...
# Dataframe is empty. No results was returned!
# --------------------------------------------------
# Extracting historical prices for GB00BQPW6Y82...
# --------------------------------------------------
# Extracting historical prices for GB00B17MMZ46...
# --------------------------------------------------
# Extracting historical prices for GB00BNGDN821...
# --------------------------------------------------
# Extracting historical prices for GB00BMX3W479...
# --------------------------------------------------
# Extracting historical prices for GB00B41H7391...
# --------------------------------------------------
# Extracting historical prices for GB00B24CT194...
# --------------------------------------------------
# Extracting historical prices for IE00B1RR8406...
# --------------------------------------------------
# Extracting historical prices for GI000A0F6407...
# --------------------------------------------------
# Extracting historical prices for GB0000031285...
# --------------------------------------------------
# Extracting historical prices for XS0163019143...
# Dataframe is empty. No results was returned!
# --------------------------------------------------
# Extracting historical prices for GB00B0LCW083...
# --------------------------------------------------
# Extracting historical prices for GB00BMJ6DW54...
# --------------------------------------------------
# Extracting historical prices for GB00B0HZPV38...
# --------------------------------------------------
# Extracting historical prices for GB00BYNVD082...
# --------------------------------------------------
# Extracting historical prices for GB00B8HX8Z88...
# --------------------------------------------------
# Extracting historical prices for GB0006043169...
# --------------------------------------------------
# Extracting historical prices for GB00BQVVS097...
# --------------------------------------------------
# Extracting historical prices for IE00BWT6H894...
# --------------------------------------------------
# Extracting historical prices for GB0034264548...
# --------------------------------------------------
# Extracting historical prices for GB00BJ34VB96...
# --------------------------------------------------
# Extracting historical prices for GB00B1WY2338...
# --------------------------------------------------
# Extracting historical prices for GB00BYZDVK82...
# --------------------------------------------------
# Extracting historical prices for GB00B1QH8P22...
# --------------------------------------------------
# Extracting historical prices for GB00BVGBWW93...
# --------------------------------------------------
# Extracting historical prices for IE0002424939...
# --------------------------------------------------
# Extracting historical prices for GB00BCKFY513...
# --------------------------------------------------
# Extracting historical prices for GB00B01FLG62...
# --------------------------------------------------
# Extracting historical prices for GB00BYRJH519...
# --------------------------------------------------
# Extracting historical prices for GB0004478896...
# --------------------------------------------------
# Extracting historical prices for GB00BYXJC278...
# --------------------------------------------------
# Extracting historical prices for GB00B0HZPV38...
# --------------------------------------------------
# Extracting historical prices for GB0005758098...
# --------------------------------------------------
# Extracting historical prices for GB0006043169...
# --------------------------------------------------
# Extracting historical prices for BMG702782084...
# --------------------------------------------------
# Extracting historical prices for GB00B43G0577...
# --------------------------------------------------
# Extracting historical prices for GB00B1Z4ST84...
# --------------------------------------------------
# Extracting historical prices for GG00BBHX2H91...
# --------------------------------------------------
# Extracting historical prices for GB00BYYK2V80...
# --------------------------------------------------
# Extracting historical prices for GB00BLJNXL82...
# --------------------------------------------------
# Extracting historical prices for GB00BJVD3B28...
# --------------------------------------------------
# Extracting historical prices for GB0003395000...
# --------------------------------------------------
# Extracting historical prices for GB0031192486...
# --------------------------------------------------
# Extracting historical prices for GB00BLP57Y95...
# --------------------------------------------------
# Extracting historical prices for GB0003318416...
# --------------------------------------------------
# Extracting historical prices for GB00BYZFZ918...
# --------------------------------------------------
# Extracting historical prices for GB0009465807...
# --------------------------------------------------
# Extracting historical prices for GB00BK1PTB77...
# --------------------------------------------------
# Extracting historical prices for GB00BQQMCJ47...
# --------------------------------------------------
# Extracting historical prices for GB00BVYVFW23...
# --------------------------------------------------
# Extracting historical prices for LU1072616219...
# --------------------------------------------------
# Extracting historical prices for GB0005774855...
# --------------------------------------------------
# Extracting historical prices for GB00B3DGH821...
# --------------------------------------------------
# Extracting historical prices for GB0009303123...
# --------------------------------------------------
# Extracting historical prices for GB00BFG1QM56...
# --------------------------------------------------
# Extracting historical prices for GB00B09LSH68...
# --------------------------------------------------
# Extracting historical prices for GB00BVC3CB83...
# --------------------------------------------------
# Extracting historical prices for GB0031429219...
# --------------------------------------------------
# Extracting historical prices for GB00BM7S7K96...
# --------------------------------------------------
# Extracting historical prices for GB0006827546...
# --------------------------------------------------
# Extracting historical prices for GB0007594764...
# --------------------------------------------------
# Extracting historical prices for GB00BWDPMF43...
# --------------------------------------------------
# Extracting historical prices for GB00B572ZV91...
# --------------------------------------------------
# Extracting historical prices for JE00BN574F90...
# --------------------------------------------------
# Extracting historical prices for GB00BVG1CF25...
# --------------------------------------------------
# Extracting historical prices for GB00BMSKPJ95...
# --------------------------------------------------
# Extracting historical prices for GB00B0672758...
# --------------------------------------------------
# Extracting historical prices for GB00BMP36W19...
# --------------------------------------------------
# Extracting historical prices for GB00B0LCW083...
# --------------------------------------------------
# Extracting historical prices for GB0009303123...
# --------------------------------------------------
# Extracting historical prices for GB0006650450...
# --------------------------------------------------
# Extracting historical prices for GB0001500809...
# --------------------------------------------------
# Extracting historical prices for GB00BD6GN030...
# Dataframe is empty. No results was returned!
# --------------------------------------------------
# Extracting historical prices for GB00B0LCW083...
# --------------------------------------------------
# Extracting historical prices for GB0001500809...
# --------------------------------------------------
# Extracting historical prices for GB00BLRLH124...
# --------------------------------------------------
# Extracting historical prices for GB0000811801...
# --------------------------------------------------
# Extracting historical prices for GB00BF044593...
# --------------------------------------------------
# Extracting historical prices for GB00B635TG28...
# --------------------------------------------------
# Extracting historical prices for GB0003345054...
# --------------------------------------------------
# Extracting historical prices for GB00B1XH2C03...
# --------------------------------------------------
# Extracting historical prices for GB00BCKFY513...
# --------------------------------------------------
# Extracting historical prices for GB00BMP36W19...
# --------------------------------------------------
# Extracting historical prices for GB00B63QSB39...
# --------------------------------------------------
# Extracting historical prices for GB00B1FW5029...
# --------------------------------------------------
# Extracting historical prices for GB00BGLP8L22...
# --------------------------------------------------
# Extracting historical prices for GB00BQPW6Y82...
# --------------------------------------------------
# Extracting historical prices for GB00B0H2K534...
# --------------------------------------------------
# Extracting historical prices for GB0004726096...
# --------------------------------------------------
# Extracting historical prices for GB00B5NFV695...
# --------------------------------------------------
# Extracting historical prices for GB0008782301...
# --------------------------------------------------
# Extracting historical prices for GB0000811801...
# --------------------------------------------------
# Extracting historical prices for GG00B2QQPT96...
# --------------------------------------------------
# Extracting historical prices for GB00BLY2F708...
# --------------------------------------------------
# Extracting historical prices for GB00BJVD3B28...
# --------------------------------------------------
# Extracting historical prices for GB0002502812...
# --------------------------------------------------
# Extracting historical prices for GB00BY9D0Y18...
# --------------------------------------------------
# Extracting historical prices for GB00B4Y7R145...
# --------------------------------------------------
# Extracting historical prices for GB00BKY7HG11...
# --------------------------------------------------
# Extracting historical prices for GB0009303123...
# --------------------------------------------------
# Extracting historical prices for GB0002520509...
# --------------------------------------------------
# Extracting historical prices for GB00BQVVS097...
# --------------------------------------------------
# Extracting historical prices for GB00BMHTPY25...
# --------------------------------------------------
# Extracting historical prices for GB00BMX64W89...
# --------------------------------------------------
# Extracting historical prices for GB00BNLPYF73...
# --------------------------------------------------
# Extracting historical prices for GB00BNGWY422...
# --------------------------------------------------
# Extracting historical prices for GB00BMQX2Q65...
# --------------------------------------------------
# Extracting historical prices for GB0001570810...
# --------------------------------------------------
# Extracting historical prices for GB00BMHTHT14...
# --------------------------------------------------
# Extracting historical prices for GB00B1YW4409...
# --------------------------------------------------
# Extracting historical prices for GI000A0F6407...
# --------------------------------------------------
# Extracting historical prices for GB00BJTNFH41...
# --------------------------------------------------
# Extracting historical prices for GB00BKRV3L73...
# --------------------------------------------------
# Extracting historical prices for GB0004228648...
# --------------------------------------------------
# Extracting historical prices for GB0006834344...
# --------------------------------------------------
# Extracting historical prices for GB00BKX5CN86...
# --------------------------------------------------
# Extracting historical prices for GB0007448250...
# --------------------------------------------------
# Extracting historical prices for JE00BJT32513...
# --------------------------------------------------
# Extracting historical prices for GB00BNGDN821...
# --------------------------------------------------
# Extracting historical prices for GB0005800072...
# --------------------------------------------------
# Extracting historical prices for GB0006111123...
# --------------------------------------------------
# Extracting historical prices for GB00B9QN7S21...
# --------------------------------------------------
# Extracting historical prices for GB00BJ62K685...
# --------------------------------------------------
# Extracting historical prices for GB00BJ34VB96...
# --------------------------------------------------
# Extracting historical prices for GB0031698896...
# --------------------------------------------------
# Extracting historical prices for GB0000282623...
# --------------------------------------------------
# Extracting historical prices for GB0000811801...
# --------------------------------------------------
# Extracting historical prices for GB0002670437...
# --------------------------------------------------
# Extracting historical prices for GB0002945029...
# --------------------------------------------------
# Extracting historical prices for JE00B2Q4TN56...
# --------------------------------------------------
# Extracting historical prices for GB00BFG1QM56...
# --------------------------------------------------
# Extracting historical prices for GB00BCRX1J15...
# --------------------------------------------------
# Extracting historical prices for IE00BDC5DG00...
# --------------------------------------------------
# Extracting historical prices for GB0007669376...
# --------------------------------------------------
# Extracting historical prices for GB00BP92CJ43...
# --------------------------------------------------
# Extracting historical prices for GB0000536739...
# --------------------------------------------------
# Extracting historical prices for GB0001772945...
# --------------------------------------------------
# Extracting historical prices for GB00B4Y7R145...
# --------------------------------------------------
# Extracting historical prices for GB00B45C9X44...
# --------------------------------------------------
# Extracting historical prices for GB00BJFFLV09...
# --------------------------------------------------
# Extracting historical prices for GB0033057794...
# --------------------------------------------------
# Extracting historical prices for GB00BCKFY513...
# --------------------------------------------------
# Extracting historical prices for IE00B00MZ448...
# --------------------------------------------------
# Extracting historical prices for GB00B63QSB39...
# --------------------------------------------------
# Extracting historical prices for GB00B1FW5029...
# --------------------------------------------------
# Extracting historical prices for GB00BM8Q5M07...
# --------------------------------------------------
# Extracting historical prices for GB0005790059...
# --------------------------------------------------
# Extracting historical prices for GB00BDZT6P94...
# --------------------------------------------------
# Extracting historical prices for GG00BBHXCL35...
# --------------------------------------------------
# Extracting historical prices for GB00BDVZYZ77...
# --------------------------------------------------
# Extracting historical prices for GB0007918872...
# --------------------------------------------------
# Extracting historical prices for GB0033277061...
# --------------------------------------------------
# Extracting historical prices for GB00B8HX8Z88...
# --------------------------------------------------
# Extracting historical prices for GB00B3KHXB36...
# --------------------------------------------------
# Extracting historical prices for GB00B5BLXT62...
# --------------------------------------------------
# Extracting historical prices for CH0198251305...
# --------------------------------------------------
# Extracting historical prices for CA29382B1022...
# --------------------------------------------------
# Extracting historical prices for GB00B29BCK10...
# --------------------------------------------------
# Extracting historical prices for IE0003864109...
# --------------------------------------------------
# Extracting historical prices for GB0003450359...
# --------------------------------------------------
# Extracting historical prices for GB00B1CRLC47...
# --------------------------------------------------
# Extracting historical prices for GB00B9QN7S21...
# --------------------------------------------------
# Extracting historical prices for GB00B1GC5238...
# --------------------------------------------------
# Extracting historical prices for GB0007973794...
# --------------------------------------------------
# Extracting historical prices for GB00B1QH8P22...
# --------------------------------------------------
# Extracting historical prices for GB00BD45S967...
# --------------------------------------------------
# Extracting historical prices for GB00B5N0P849...
# --------------------------------------------------
# Extracting historical prices for GB00BK5V9445...
# --------------------------------------------------
# Extracting historical prices for GB00B8VZXT93...
# --------------------------------------------------
# Extracting historical prices for GB00BF8Q6K64...
# --------------------------------------------------
# Extracting historical prices for GB0032287020...
# --------------------------------------------------
# Extracting historical prices for GB00BF8Q6K64...
# --------------------------------------------------
# Extracting historical prices for GB00B71N6K86...
# --------------------------------------------------
# Extracting historical prices for JE00B2Q4TN56...
# --------------------------------------------------
# Extracting historical prices for GB00B42CTW68...
# --------------------------------------------------
# Extracting historical prices for GB0006825383...
# --------------------------------------------------
# Extracting historical prices for GB0031544546...
# --------------------------------------------------
# Extracting historical prices for JE00B6T5S470...
# --------------------------------------------------
# Extracting historical prices for GB0009376368...
# --------------------------------------------------
# Extracting historical prices for GB00BK9RKT01...
# --------------------------------------------------
# Extracting historical prices for GB0001570810...
# --------------------------------------------------
# Extracting historical prices for GI000A0F6407...
# --------------------------------------------------
# Extracting historical prices for GB0001297562...
# --------------------------------------------------
# Extracting historical prices for GB00B7KR2P84...
# --------------------------------------------------
# Extracting historical prices for GB0006834344...
# --------------------------------------------------
# Extracting historical prices for GB00BF8Q6K64...
# --------------------------------------------------
# Extracting historical prices for GB00B0HZPV38...
# --------------------------------------------------
# Extracting historical prices for GB0004866223...
# --------------------------------------------------
# Extracting historical prices for GB00B0SWJX34...
# --------------------------------------------------
# Extracting historical prices for GB00B7FC0762...
# --------------------------------------------------
# Extracting historical prices for GB00B0D5V538...
# --------------------------------------------------
# Extracting historical prices for GB00B03HDJ73...
# --------------------------------------------------
# Extracting historical prices for GB00B1VYCH82 ...
# Dataframe is empty. No results was returned!
# --------------------------------------------------
# /var/folders/mv/kbtg0d9s34s4w1xjw4w31b0h0000gn/T/ipykernel_76528/380360628.py:49: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pd.
# ===================================================

# %%
ftse_rebal_data = historical_prices.reset_index().copy()

lst_isin = list(ftse_full_rebal["ISIN"])
lst_date = list(ftse_full_rebal["Post Date"])

# %%
def get_price(df, isin, date):
    pre_twenty_pd = []
    pre_five_pd = []
    pre_three_pd = []
    pre_one_pd = []
    post_three_pd = []
    post_five_pd = []
    post_ten_pd = []
    post_twenty_pd = []
    merge_lst = []
    lst_rm = []
    lst_date = []
    
    for i in range(len(isin)):
        try:
            index = df.index[(df["trade_date"] == date[i]) & (df["isin_code"] == isin[i])][0]
            
            pre_twenty_pd.append(df["close"].iloc[index - 20])
            pre_five_pd.append(df["close"].iloc[index - 5])
            pre_three_pd.append(df["close"].iloc[index - 3])
            pre_one_pd.append(df["close"].iloc[index - 1])
            post_three_pd.append(df["close"].iloc[index + 3])
            post_five_pd.append(df["close"].iloc[index + 5])
            post_ten_pd.append(df["close"].iloc[index + 10])
            post_twenty_pd.append(df["close"].iloc[index + 20])
            
            merge_lst.append(pre_twenty_pd)   
            merge_lst.append(pre_five_pd)
            merge_lst.append(pre_three_pd)
            merge_lst.append(pre_one_pd)
            merge_lst.append(post_three_pd)
            merge_lst.append(post_five_pd)
            merge_lst.append(post_ten_pd)
            merge_lst.append(post_twenty_pd)
        
        except IndexError:
            print(isin[i], date[i])
            lst_rm.append(isin[i])
            lst_date.append(date[i])
            next 
        
    return merge_lst, lst_rm, lst_date

# %%
lst_ftse_price, rm_lst, rm_date = get_price(ftse_rebal_data, lst_isin, lst_date)
# Out:
# GB00BRJ7R218 19/6/2023
# GB00BF8Q6K64 19/9/2022
# GG00BB0RDB98 19/9/2022
# GG00BGJYPP46 19/9/2022
# GB00BD3VFW73 19/9/2022
# GB0003466074 19/9/2022
# IE0003864109 19/9/2022
# GB00BMBVGQ36 19/9/2022
# GB00B0LCW083 19/9/2022
# GB0005576813 19/9/2022
# GG00BJ0JVY01 19/9/2022
# GB00B1Z4ST84 19/9/2022
# GB00BY2Z0H74 19/9/2022
# GG00B90J5Z95 19/9/2022
# GB00B29H4253 19/9/2022
# GB00BD2NCM38 19/9/2022
# SG9999003735 19/9/2022
# GB00B71N6K86 21/3/2022
# GB00BJ7HMW26 21/9/2020
# GB00BJ7HMW26 23/3/2020
# GB00B1VYCH82  24/12/2018
# GB0001528156 20/6/2016
# XS0163019143 21/3/2016
# GB00BD6GN030 23/3/2015
# GB00B1VYCH82  18/3/2013

# %%
lst_index = []
for i in range(len(rm_lst)):
    #print(rm_lst[i])
    index = ftse_full_rebal.index[(ftse_full_rebal["ISIN"] == rm_lst[i]) & (ftse_full_rebal["post_date"] == rm_date[i])][0]
    lst_index.append(index)
    
rm_ftse_full_rebal = ftse_full_rebal.copy()
rm_ftse_full_rebal = ftse_full_rebal.drop(lst_index)
rm_ftse_full_rebal = rm_ftse_full_rebal.copy().reset_index()

# %%
ftse_tidy_data = pd.DataFrame()

ftse_tidy_data["Name"] = rm_ftse_full_rebal["Name"]
#ftse_tidy_data["ICB_Code"] = rm_ftse_full_rebal["Name"]

#ftse_tidy_data["SEDOL"] = rm_ftse_full_rebal["SEDOL\n"]
ftse_tidy_data["ISIN"] = rm_ftse_full_rebal["ISIN"]
ftse_tidy_data["FTSE100"] = rm_ftse_full_rebal["FTSE100"]
ftse_tidy_data["FTSE250"] = rm_ftse_full_rebal["FTSE250"]
ftse_tidy_data["post_date"] = rm_ftse_full_rebal["post_date"]

# %%
ftse_tidy_data["pre_twenty_pd"] = lst_ftse_price[0]
ftse_tidy_data["pre_five_pd"] = lst_ftse_price[1]
ftse_tidy_data["pre_three_pd"] = lst_ftse_price[2]
ftse_tidy_data["pre_one_pd"] = lst_ftse_price[3]
ftse_tidy_data["post_three_pd"] = lst_ftse_price[4]
ftse_tidy_data["post_five_pd"] = lst_ftse_price[5]
ftse_tidy_data["post_ten_pd"] = lst_ftse_price[6]
ftse_tidy_data["post_twenty_pd"] = lst_ftse_price[7]

# %%
ftse_tidy_data["diff_twenty_three"] = ftse_tidy_data["post_three_pd"] - ftse_tidy_data["pre_twenty_pd"]
ftse_tidy_data["diff_twenty_five"] = ftse_tidy_data["post_five_pd"] - ftse_tidy_data["pre_twenty_pd"]
ftse_tidy_data["diff_twenty_ten"] = ftse_tidy_data["post_ten_pd"] - ftse_tidy_data["pre_twenty_pd"]
ftse_tidy_data["diff_twenty_twenty"] = ftse_tidy_data["post_twenty_pd"] - ftse_tidy_data["pre_twenty_pd"]

ftse_tidy_data["diff_five_three"] = ftse_tidy_data["post_three_pd"] - ftse_tidy_data["pre_five_pd"]
ftse_tidy_data["diff_five_five"] = ftse_tidy_data["post_five_pd"] - ftse_tidy_data["pre_five_pd"]
ftse_tidy_data["diff_five_ten"] = ftse_tidy_data["post_ten_pd"] - ftse_tidy_data["pre_five_pd"]
ftse_tidy_data["diff_five_twenty"] = ftse_tidy_data["post_twenty_pd"] - ftse_tidy_data["pre_five_pd"]

ftse_tidy_data["diff_three_three"] = ftse_tidy_data["post_three_pd"] - ftse_tidy_data["pre_three_pd"]
ftse_tidy_data["diff_three_five"] = ftse_tidy_data["post_five_pd"] - ftse_tidy_data["pre_three_pd"]
ftse_tidy_data["diff_three_ten"] = ftse_tidy_data["post_ten_pd"] - ftse_tidy_data["pre_three_pd"]
ftse_tidy_data["diff_three_twenty"] = ftse_tidy_data["post_twenty_pd"] - ftse_tidy_data["pre_three_pd"]


ftse_tidy_data["diff_one_three"] = ftse_tidy_data["post_three_pd"] - ftse_tidy_data["pre_one_pd"]
ftse_tidy_data["diff_one_five"] = ftse_tidy_data["post_five_pd"] - ftse_tidy_data["pre_one_pd"]
ftse_tidy_data["diff_one_ten"] = ftse_tidy_data["post_ten_pd"] - ftse_tidy_data["pre_one_pd"]
ftse_tidy_data["diff_one_twenty"] = ftse_tidy_data["post_twenty_pd"] - ftse_tidy_data["pre_one_pd"]

# %%
df_isin = pd.DataFrame()
df_isin["isin"] = lst_isin
df_isin.to_csv(f'/Users/abigail/Desktop/SMU/QF603/output/isins.csv')

# %%
ftse_tidy_data.to_csv(
            f'/Users/abigail/Desktop/SMU/QF603/output/partial2_ETL_10Y_ftse_price_data.csv',
            index = False
            )

# %%
# lst_date[0]
ftse_full_rebal.index[(ftse_full_rebal["ISIN"] == rm_lst[0]) & (ftse_full_rebal["post_date"] == rm_date[0])][0]
# Out:
# 23

# %%
ftse_full_rebal["ISIN"]
# Out:
# 0       GI000A0F6407
# 1       GB00BF8Q6K64
# 2       GB00BM8NFJ84
# 3       GB00BMCYKB41
# 4       GB00B23K0M20
#            ...
# 576     GB00B0SWJX34
# 577     GB00B7FC0762
# 578     GB00B0D5V538
# 579     GB00B03HDJ73
# 580    GB00B1VYCH82
# Name: ISIN, Length: 581, dtype: object

# %%
ftse_rebal_data["isin_code"].isin(list(lst_isin[1])) == True  #and ftse_rebal_data["trade_date"].isin(list(lst_date[1]))
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29190    False
# 29191    False
# 29192    False
# 29193    False
# 29194    False
# Name: isin_code, Length: 29195, dtype: bool

# %%
historical_prices
# Out:
#    trade_date  security_code security_name primary_exchange  refinitiv_code  \
# 0  2022-06-10         4801.0          ASOS              LON          9204.0
# 1  2022-06-13         4801.0          ASOS              LON          9204.0
# 2  2022-06-14         4801.0          ASOS              LON          9204.0
# 3  2022-06-15         4801.0          ASOS              LON          9204.0
# 4  2022-06-16         4801.0          ASOS              LON          9204.0
# ..        ...            ...           ...              ...             ...
# 25 2023-07-14        50711.0      VIDENDUM              LON         46848.0
# 26 2023-07-17        50711.0      VIDENDUM              LON         46848.0
# 27 2023-07-18        50711.0      VIDENDUM              LON         46848.0
# 28 2023-07-19        50711.0      VIDENDUM              LON         46848.0
# 29 2023-07-20        50711.0      VIDENDUM              LON         46848.0
#
#        isin_code currency       open       high        low      close  \
# 0   GB0030927254      GBP  13.699998  13.720000  12.960000  12.989998
# 1   GB0030927254      GBP  12.850000  12.850000  12.090000  12.090000
# 2   GB0030927254      GBP  12.239998  12.420000  11.100000  11.220000
# 3   GB0030927254      GBP  11.409998  11.770000  11.165076  11.600000
# 4   GB0030927254      GBP  10.300000  10.399998   7.750000   7.835000
# ..           ...      ...        ...        ...        ...        ...
# 25  GB0009296665      GBP   5.989998   6.149998   5.850000   5.970000
# 26  GB0009296665      GBP   5.890000   6.380000   5.890000   6.000000
# 27  GB0009296665      GBP   6.050000   6.050000   5.979998   6.000000
# 28  GB0009296665      GBP   6.000000   6.050000   5.970000   6.000000
# 29  GB0009296665      GBP   6.050000   6.050000   5.960000   6.000000
#
#        volume
# 0    889130.0
# 1    545975.0
# 2   1058657.0
# 3   1124355.0
# 4   3501290.0
# ..        ...
# 25    52469.0
# 26   265319.0
# 27   356825.0
# 28   303385.0
# 29    69776.0
#
# [1885 rows x 12 columns]

# %%
new_df = pd.DataFrame()
new_df['open'] = historical_prices['open']
new_df['high'] = historical_prices['high']
new_df['low'] = historical_prices['low']

# %%
data = new_df.corr()

# %%
data.iloc[0,1]
# Out:
# 0.9997790177972949

# %%
data.size()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 data.size()
#
# TypeError: 'int' object is not callable

# %%
for i in range(len(data.columns)):
    print(data.iloc[0,i])
# Out:
# 1.0
# 0.9997790177972949
# 0.9997264110283793

# %%
lst_isin[0]

i = 1
'pd_grp_' + str(i)
# Out:
# 'GB0030927254'

# %%
ftse_rebal_data
# Out:
#        index trade_date  security_code      security_name primary_exchange  \
# 0          0 2023-08-09        18982.0       888 HOLDINGS              LON
# 1          1 2023-08-10        18982.0       888 HOLDINGS              LON
# 2          2 2023-08-11        18982.0       888 HOLDINGS              LON
# 3          3 2023-08-14        18982.0       888 HOLDINGS              LON
# 4          4 2023-08-15        18982.0       888 HOLDINGS              LON
# ...      ...        ...            ...                ...              ...
# 29190     45 2013-04-12        54340.0  ESKEN LIMITED 10P              LON
# 29191     46 2013-04-15        54340.0  ESKEN LIMITED 10P              LON
# 29192     47 2013-04-16        54340.0  ESKEN LIMITED 10P              LON
# 29193     48 2013-04-17        54340.0  ESKEN LIMITED 10P              LON
# 29194     49 2013-04-18        54340.0  ESKEN LIMITED 10P              LON
#
#        refinitiv_code     isin_code currency    open      high       low  \
# 0             26862.0  GI000A0F6407      GBP  1.0660  1.136000  1.063000
# 1             26862.0  GI000A0F6407      GBP  1.1400  1.140000  1.091000
# 2             26862.0  GI000A0F6407      GBP  1.1000  1.331000  1.098000
# 3             26862.0  GI000A0F6407      GBP  1.1470  1.160000  1.088108
# 4             26862.0  GI000A0F6407      GBP  1.1000  1.126000  1.001000
# ...               ...           ...      ...     ...       ...       ...
# 29190         21865.0  GB00B03HDJ73      GBP  0.7900  0.817425  0.777500
# 29191         21865.0  GB00B03HDJ73      GBP  0.7700  0.787000  0.745000
# 29192         21865.0  GB00B03HDJ73      GBP  0.7800  0.792500  0.760000
# 29193         21865.0  GB00B03HDJ73      GBP  0.7625  0.786250  0.740380
# 29194         21865.0  GB00B03HDJ73      GBP  0.7575  0.769357  0.735800
#
#         close     volume
# 0      1.1170   358252.0
# 1      1.1200   284950.0
# 2      1.1500  1003896.0
# 3      1.0960  1088784.0
# 4      1.1140  1127118.0
# ...       ...        ...
# 29190  0.7775   806035.0
# 29191  0.7750   561623.0
# 29192  0.7600   594090.0
# 29193  0.7500   352065.0
# 29194  0.7450   466543.0
#
# [29195 rows x 13 columns]

# %%
ftse_full_rebal
# Out:
#             Ticker                                             Name  SEDOL\n  \
# 0    ASC LN Equity                                         ASOS PLC  3092725
# 1   BGEO LN Equity                        Bank of Georgia Group PLC  BF4HYT8
# 2    CLG LN Equity                          GXO Logistics UK II Ltd  BMMV6B7
# 3    CNA LN Equity                                     Centrica PLC  B033F22
# 4    IDS LN Equity         International Distributions Services PLC  BDVZYZ7
# ..             ...                                              ...      ...
# 67  MEGP LN Equity                       ME GROUP INTERNATIONAL PLC  0848125
# 68   NAS LN Equity  North Atlantic Smaller Cos Investment Trust PLC  0643900
# 69   TLW LN Equity                                   Tullow Oil PLC  0150080
# 70  TYMN LN Equity                                        Tyman PLC  B29H425
# 71   VID LN Equity                                     VIDENDUM PLC  0929666
#
#           ISIN\n  FTSE100  FTSE250 Market Cap (Pre) Market Cap (Post)  \
# 0   GB0030927254      NaN      1.0              NaN         870979136
# 1   GB00BF4HYT85      NaN      1.0              NaN         738524800
# 2   GB00BMMV6B79      NaN     -1.0        874229248               NaN
# 3   GB00B033F229      1.0     -1.0       4912636928        4763841536
# 4   GB00BDVZYZ77     -1.0      1.0       2999578880        2687859968
# ..           ...      ...      ...              ...               ...
# 67  GB0008481250      NaN      1.0              NaN         608598720
# 68  GB0006439003      NaN      1.0              NaN                --
# 69  GB0001500809      NaN     -1.0      361791968.0               NaN
# 70  GB00B29H4253      NaN      1.0              NaN         523000384
# 71  GB0009296665      NaN     -1.0      330834592.0               NaN
#
#      Post Date  post_date start_date   end_date fmt_start_date fmt_end_date
# 0   2022-06-20 2022-06-20 2022-06-10 2022-07-21     10/06/2022   21/07/2022
# 1   2022-06-20 2022-06-20 2022-06-10 2022-07-21     10/06/2022   21/07/2022
# 2   2022-06-20 2022-06-20 2022-06-10 2022-07-21     10/06/2022   21/07/2022
# 3   2022-06-20 2022-06-20 2022-06-10 2022-07-21     10/06/2022   21/07/2022
# 4   2022-06-20 2022-06-20 2022-06-10 2022-07-21     10/06/2022   21/07/2022
# ..         ...        ...        ...        ...            ...          ...
# 67  2023-06-19 2023-06-19 2023-06-09 2023-07-20     09/06/2023   20/07/2023
# 68  2023-06-19 2023-06-19 2023-06-09 2023-07-20     09/06/2023   20/07/2023
# 69  2023-06-19 2023-06-19 2023-06-09 2023-07-20     09/06/2023   20/07/2023
# 70  2023-06-19 2023-06-19 2023-06-09 2023-07-20     09/06/2023   20/07/2023
# 71  2023-06-19 2023-06-19 2023-06-09 2023-07-20     09/06/2023   20/07/2023
#
# [72 rows x 14 columns]
